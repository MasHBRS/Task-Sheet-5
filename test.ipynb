# %%
import torch as t

# %%
h1=t.rand(1, 7)
h2=t.rand(1,7)
h1+h2
# Out:
# tensor([[1.7394, 1.1002, 0.2266, 1.4358, 1.7027, 1.5105, 0.8963]])

# %%
0.9877*0.9389+ 0.3043*0.7557+ 0.8279*0.2279+ 0.9305*0.5858+ 0.5580*0.5151 +0.7859*0.4979+ 0.8220*0.9758
# Out:
# 3.3719093599999996
